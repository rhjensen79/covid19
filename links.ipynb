# %%
import requests 
from bs4 import BeautifulSoup 
import pandas as pd

# %%
url = 'https://github.com/CSSEGISandData/COVID-19/tree/master/csse_covid_19_data/csse_covid_19_daily_reports'
reqs = requests.get(url) 
soup = BeautifulSoup(reqs.text, 'html.parser')

# %%
urls = [] 
for link in soup.find_all('a'): 
    if link['href'].endswith('.csv'):
        print(link.get('href'))
# Out:
# v
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-10-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-11-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-12-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-13-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-14-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-15-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-16-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-17-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-18-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-19-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-20-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-21-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-22-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-23-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-24-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-25-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-26-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-27-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-28-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-29-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/06-30-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-01-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-02-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-03-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-04-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-05-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-06-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-07-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-08-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-09-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-10-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-11-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-12-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-13-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-14-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-15-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-16-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-17-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-18-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-19-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-20-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-21-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-22-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-23-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-24-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-25-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-26-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-27-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-28-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-29-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-30-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/07-31-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-01-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-02-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-03-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-04-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-05-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-06-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-07-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-08-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-09-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-10-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-11-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-12-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-13-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-14-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-15-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-16-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-17-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-18-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-19-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-20-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-21-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-22-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-23-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-24-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-25-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-26-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-27-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-28-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-29-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-30-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/08-31-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-01-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-02-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-03-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-04-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-05-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-06-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-07-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-08-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-09-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-10-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-11-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-12-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-13-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-14-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-15-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-16-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-17-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-18-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-19-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-20-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-21-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-22-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-23-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-24-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-25-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-26-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-27-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-28-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-29-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/09-30-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-01-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-02-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-03-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-04-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-05-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-06-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-07-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-08-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-09-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-10-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-11-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-12-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-13-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-14-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-15-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-16-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-17-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-18-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-19-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-20-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-21-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-22-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-23-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-24-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-25-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-26-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-27-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-28-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-29-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-30-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/10-31-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-01-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-02-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-03-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-04-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-05-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-06-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-07-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-08-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-09-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-10-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-11-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-12-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-13-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-14-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-15-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-16-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-17-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-18-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-19-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-20-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-21-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-22-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-23-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-24-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-25-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-26-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-27-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-28-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-29-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/11-30-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-01-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-02-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-03-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-04-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-05-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-06-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-07-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-08-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-09-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-10-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-11-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-12-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-13-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-14-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-15-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-16-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-17-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-18-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-19-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-20-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-21-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-22-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-23-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-24-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-25-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-26-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-27-2020.csv
# /CSSEGISandData/COVID-19/blob/master/csse_covid_19_data/csse_covid_19_daily_reports/12-28-2020.csv

# %%
urls = [] 
for link in soup.find_all('a'): 
    if link['href'].endswith('.csv'):
        csv_url = ("https://raw.githubusercontent.com"+link.get('href')) 
        #print (csv_url)
        csv_url = csv_url.replace('/blob', '')
        print (csv_url)
        #print("https://raw.githubusercontent.com"+link.get('href')) 
        data = pd.read_csv(csv_url) 
        #data = data[(data['Country_Region'] == 'Denmark') & (data['Province_State'] != 'Faroe Islands') & (data['Province_State'] != 'Greenland')]
        print (data)
# Out:
# https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/01-22-2020.csv
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# /usr/local/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1341             try:
# -> 1342                 h.request(req.get_method(), req.selector, req.data, headers,
#    1343                           encode_chunked=req.has_header('Transfer-encoding'))
#
# /usr/local/lib/python3.9/http/client.py in request(self, method, url, body, headers, encode_chunked)
#    1254         """Send a complete request to the server."""
# -> 1255         self._send_request(method, url, body, headers, encode_chunked)
#    1256
#
# /usr/local/lib/python3.9/http/client.py in _send_request(self, method, url, body, headers, encode_chunked)
#    1300             body = _encode(body, 'body')
# -> 1301         self.endheaders(body, encode_chunked=encode_chunked)
#    1302
#
# /usr/local/lib/python3.9/http/client.py in endheaders(self, message_body, encode_chunked)
#    1249             raise CannotSendHeader()
# -> 1250         self._send_output(message_body, encode_chunked=encode_chunked)
#    1251
#
# /usr/local/lib/python3.9/http/client.py in _send_output(self, message_body, encode_chunked)
#    1009         del self._buffer[:]
# -> 1010         self.send(msg)
#    1011
#
# /usr/local/lib/python3.9/http/client.py in send(self, data)
#     949             if self.auto_open:
# --> 950                 self.connect()
#     951             else:
#
# /usr/local/lib/python3.9/http/client.py in connect(self)
#    1416
# -> 1417             super().connect()
#    1418
#
# /usr/local/lib/python3.9/http/client.py in connect(self)
#     920         """Connect to the host and port specified in __init__."""
# --> 921         self.sock = self._create_connection(
#     922             (self.host,self.port), self.timeout, self.source_address)
#
# /usr/local/lib/python3.9/socket.py in create_connection(address, timeout, source_address)
#     842         try:
# --> 843             raise err
#     844         finally:
#
# /usr/local/lib/python3.9/socket.py in create_connection(address, timeout, source_address)
#     830                 sock.bind(source_address)
# --> 831             sock.connect(sa)
#     832             # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 111] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# URLError                                  Traceback (most recent call last)
# <ipython-input-59-bcc036b7fa3c> in <module>
#       7         print (csv_url)
#       8         #print("https://raw.githubusercontent.com"+link.get('href'))
# ----> 9         data = pd.read_csv(csv_url)
#      10         #data = data[(data['Country_Region'] == 'Denmark') & (data['Province_State'] != 'Faroe Islands') & (data['Province_State'] != 'Greenland')]
#      11         print (data)
#
# ~/.local/lib/python3.9/site-packages/pandas/io/parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     603     kwds.update(kwds_defaults)
#     604
# --> 605     return _read(filepath_or_buffer, kwds)
#     606
#     607
#
# ~/.local/lib/python3.9/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     455
#     456     # Create the parser.
# --> 457     parser = TextFileReader(filepath_or_buffer, **kwds)
#     458
#     459     if chunksize or iterator:
#
# ~/.local/lib/python3.9/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options["has_index_names"] = kwds["has_index_names"]
#     813
# --> 814         self._engine = self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# ~/.local/lib/python3.9/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1043             )
#    1044         # error: Too many arguments for "ParserBase"
# -> 1045         return mapping[engine](self.f, **self.options)  # type: ignore[call-arg]
#    1046
#    1047     def _failover_to_python(self):
#
# ~/.local/lib/python3.9/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1860
#    1861         # open handles
# -> 1862         self._open_handles(src, kwds)
#    1863         assert self.handles is not None
#    1864         for key in ("storage_options", "encoding", "memory_map", "compression"):
#
# ~/.local/lib/python3.9/site-packages/pandas/io/parsers.py in _open_handles(self, src, kwds)
#    1355         Let the readers open IOHanldes after they are done with their potential raises.
#    1356         """
# -> 1357         self.handles = get_handle(
#    1358             src,
#    1359             "r",
#
# ~/.local/lib/python3.9/site-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     556
#     557     # open URLs
# --> 558     ioargs = _get_filepath_or_buffer(
#     559         path_or_buf,
#     560         encoding=encoding,
#
# ~/.local/lib/python3.9/site-packages/pandas/io/common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     286                 "storage_options passed with file object or non-fsspec file path"
#     287             )
# --> 288         req = urlopen(filepath_or_buffer)
#     289         content_encoding = req.headers.get("Content-Encoding", None)
#     290         if content_encoding == "gzip":
#
# ~/.local/lib/python3.9/site-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     192     import urllib.request
#     193
# --> 194     return urllib.request.urlopen(*args, **kwargs)
#     195
#     196
#
# /usr/local/lib/python3.9/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     212     else:
#     213         opener = _opener
# --> 214     return opener.open(url, data, timeout)
#     215
#     216 def install_opener(opener):
#
# /usr/local/lib/python3.9/urllib/request.py in open(self, fullurl, data, timeout)
#     515
#     516         sys.audit('urllib.Request', req.full_url, req.data, req.headers, req.get_method())
# --> 517         response = self._open(req, data)
#     518
#     519         # post-process response
#
# /usr/local/lib/python3.9/urllib/request.py in _open(self, req, data)
#     532
#     533         protocol = req.type
# --> 534         result = self._call_chain(self.handle_open, protocol, protocol +
#     535                                   '_open', req)
#     536         if result:
#
# /usr/local/lib/python3.9/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     492         for handler in handlers:
#     493             func = getattr(handler, meth_name)
# --> 494             result = func(*args)
#     495             if result is not None:
#     496                 return result
#
# /usr/local/lib/python3.9/urllib/request.py in https_open(self, req)
#    1383
#    1384         def https_open(self, req):
# -> 1385             return self.do_open(http.client.HTTPSConnection, req,
#    1386                 context=self._context, check_hostname=self._check_hostname)
#    1387
#
# /usr/local/lib/python3.9/urllib/request.py in do_open(self, http_class, req, **http_conn_args)
#    1343                           encode_chunked=req.has_header('Transfer-encoding'))
#    1344             except OSError as err: # timeout error
# -> 1345                 raise URLError(err)
#    1346             r = h.getresponse()
#    1347         except:
#
# URLError: <urlopen error [Errno 111] Connection refused>
